# %% [markdown]
# # Intersect Clustering

# %% [markdown]
# ## 0. Preliminaries
#
# ### 0.1. Import dependencies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 0.2. Load data

# %%
data = pd.read_csv("../data/ohsumed-clean-disease.csv")

# %%
text_col = "text"
label_col = "Category"

# %%
data[label_col].value_counts()
# Out:
# Neoplasms                                              6070
# Cardiovascular Diseases                                4657
# Nervous System Diseases                                2844
# Bacterial Infections and Mycoses                       2540
# Digestive System Diseases                              2144
# Pathological Conditions                                1924
# Respiratory Tract Diseases                             1650
# Urologic and Male Genital Diseases                     1583
# Disorders of Environmental Origin                      1572
# Musculoskeletal Diseases                               1376
# Immunologic Diseases                                   1308
# Nutritional and Metabolic Diseases                     1049
# Virus Diseases                                          983
# Female Genital Diseases and Pregnancy Complications     902
# Skin and Connective Tissue Diseases                     798
# Eye Diseases                                            639
# Hemic and Lymphatic Diseases                            504
# Neonatal Diseases and Abnormalities                     496
# Otorhinolaryngologic Diseases                           381
# Parasitic Diseases                                      377
# Stomatognathic Diseases                                 284
# Endocrine Diseases                                      237
# Animal Diseases                                          71
# Name: Category, dtype: int64

# %% [markdown]
# ## 1. Create Words data structures

# %%
word_encoding_dict = dict()
label_encoding_dict = dict()

presence_word_dict = dict()
presence_label_dict = dict()

num_words = num_labels = 0
for i, (text, label) in enumerate(zip(data[text_col], data[label_col])):
    # Label encoding
    if label in label_encoding_dict:
        presence_label_dict[label_encoding_dict[label]].add(i)
    else:
        num_labels += 1
        label_encoding_dict[label] = num_labels
        presence_label_dict[num_labels] = {i}
    # Text encoding
    splitted = text.split(" ")
    for word in splitted:
        if word in word_encoding_dict:
            presence_word_dict[word_encoding_dict[word]].add(i)
        else:
            num_words += 1
            word_encoding_dict[word] = num_words
            presence_word_dict[num_words] = {i}

# %% [markdown]
# ## 2. Predict

# %%
matrix_intersection = {}

for i, (text, target) in enumerate(zip(data[text_col], data[label_col])):
    print(f"{i}/{len(data)}")
    splitted = list(set(text.split(" ")))
    # Create clusters
    clusters = []
    for j in range(len(splitted) - 1):
        a = word_encoding_dict[splitted[j]]
        for k in range(j+1, len(splitted)):
            b = word_encoding_dict[splitted[k]]
            min_index = min(a, b)
            max_index = max(a, b)
            
            if min_index in matrix_intersection:
                if max_index in matrix_intersection[min_index]:
                    intersection = matrix_intersection[min_index][max_index]
                else:
                    intersection = len(presence_word_dict[a] & presence_word_dict[b])
                    matrix_intersection[min_index][max_index] = intersection
            else:
                matrix_intersection[min_index] = dict()
                intersection = len(presence_word_dict[a] & presence_word_dict[b])
                matrix_intersection[min_index][max_index] = intersection
            if intersection > 0:
                clusters.append({
                    "a": min_index,
                    "b": max_index,
                    "intersection": intersection
                })
            #if len(intersection) > 0:
            #    clusters.append({
            #        "a": min_index,
            #        "b": max_index,
            #        "intersection": len(intersection)
            #    })
    # Sort the clusters
    sorted_clusters = sorted(clusters, key=lambda x: x['intersection'], reverse=True)
    # Create the partition
    covered_elements = set()
    remaining = len(splitted)
    partition = []
    k = 0.5
    probs = {}
    for cluster in sorted_clusters:
        a = cluster['a']
        b = cluster['b']
        if a not in covered_elements and b not in covered_elements:
            #partition.append(cluster)
            covered_elements.add(a)
            covered_elements.add(b)
            remaining -= 2
            counts = data.iloc[list(presence_word_dict[a] & 
                                    presence_word_dict[b])]['Category'].value_counts()
            # Compute the probabilities for the cluster
            for count in counts.iteritems():
                label = label_encoding_dict[count[0]]
                prob = (k + count[1]) / (2 * k + counts.sum())
                if label in probs:
                    probs[label].append(prob)
                else:
                    probs[label] = [prob]

        if remaining < 1: # There is no one left to add with a intersection
            break
    # Compute the prior probabilities (log-space to prevent precision issues)
    prioris = {}
    for label, prob_list in probs.items():
        p = 0  # Start with 0 for summation in log-space

        # Sum the log-probabilities for the present elements
        for prob in prob_list:
            p += np.log(prob)

        # Account for the clusters where the label is absent
        absent_clusters = len(partition) - len(prob_list)
        if absent_clusters > 0:
            p += absent_clusters * np.log(k / (2 * k))

        prioris[label] = p

    # Compute the global prior counts for each label
    count_labels = data[label_col].value_counts().to_dict()
    count_labels = {label_encoding_dict[label]: count_labels[label] for label in count_labels}

    # Naive Bayes denominator (in log-space for stability)
    log_denominator = None
    for label in count_labels:
        log_value = prioris[label] + np.log(count_labels[label])
        log_denominator = np.logaddexp(log_denominator, log_value) if log_denominator is not None else log_value

    # Determine the label with the maximum posterior probability
    max_prob = -np.inf
    max_label = None
    posterioris = {}
    for label in count_labels:
        log_numerator = prioris[label] + np.log(count_labels[label])
        posterior_prob = np.exp(log_numerator - log_denominator)  # Convert back to probability space
        posterioris[label] = posterior_prob
        if posterior_prob > max_prob:
            max_prob = posterior_prob
            max_label = label

    # Result
    print(f"Predicted Label: {max_label}, Probability: {max_prob} | Real: {label_encoding_dict[target]}")
    if i > 100:
        break
# Out:
# 0/34389
# Predicted Label: 22, Probability: 0.9745370508103507 | Real: 1
# 1/34389
# Predicted Label: 4, Probability: 0.9951238636412494 | Real: 1
# 2/34389
# Predicted Label: 22, Probability: 0.9999999526941548 | Real: 1
# 3/34389
# Predicted Label: 22, Probability: 0.8419260805609841 | Real: 1
# 4/34389
# Predicted Label: 14, Probability: 0.9134630886035676 | Real: 1
# 5/34389
# Predicted Label: 14, Probability: 0.987387246363313 | Real: 1
# 6/34389
# Predicted Label: 22, Probability: 0.9241297230711591 | Real: 1
# 7/34389
# Predicted Label: 4, Probability: 0.5613257636363793 | Real: 1
# 8/34389
# Predicted Label: 22, Probability: 0.9491182104829627 | Real: 1
# 9/34389
# Predicted Label: 22, Probability: 0.9993455624269243 | Real: 1
# 10/34389
# Predicted Label: 14, Probability: 0.9999997481262317 | Real: 1
# 11/34389
# Predicted Label: 4, Probability: 0.8509332031697635 | Real: 1
# 12/34389
# Predicted Label: 22, Probability: 0.9261462487212238 | Real: 1
# 13/34389
# Predicted Label: 22, Probability: 0.9960840588476098 | Real: 1
# 14/34389
# Predicted Label: 14, Probability: 0.9260010569051715 | Real: 1
# 15/34389
# Predicted Label: 4, Probability: 0.927844748589382 | Real: 1
# 16/34389
# Predicted Label: 4, Probability: 0.9861959355369774 | Real: 1
# 17/34389
# Predicted Label: 14, Probability: 0.7363985557544298 | Real: 1
# 18/34389
# Predicted Label: 14, Probability: 0.9796020202693462 | Real: 1
# 19/34389
# Predicted Label: 14, Probability: 0.9856156523771992 | Real: 1
# 20/34389
# Predicted Label: 14, Probability: 0.99712512494723 | Real: 1
# 21/34389
# Predicted Label: 14, Probability: 0.9992245577287173 | Real: 1
# 22/34389
# Predicted Label: 22, Probability: 0.8778126683760598 | Real: 1
# 23/34389
# Predicted Label: 14, Probability: 0.9999987919904831 | Real: 1
# 24/34389
# Predicted Label: 4, Probability: 0.9566076106145782 | Real: 1
# 25/34389
# Predicted Label: 14, Probability: 0.9462851016217072 | Real: 1
# 26/34389
# Predicted Label: 4, Probability: 0.7282988974248101 | Real: 1
# 27/34389
# Predicted Label: 4, Probability: 0.9969413381783175 | Real: 1
# 28/34389
# Predicted Label: 14, Probability: 0.9996808556536969 | Real: 1
# 29/34389
# Predicted Label: 14, Probability: 0.6706355533730731 | Real: 1
# 30/34389
# Predicted Label: 4, Probability: 0.5153770845430198 | Real: 1
# 31/34389
# Predicted Label: 4, Probability: 0.6912957333718464 | Real: 1
# 32/34389
# Predicted Label: 14, Probability: 0.9100067979352617 | Real: 1
# 33/34389
# Predicted Label: 14, Probability: 0.7726233744202424 | Real: 1
# 34/34389
# Predicted Label: 4, Probability: 0.9999496249691141 | Real: 1
# 35/34389
# Predicted Label: 22, Probability: 0.9999998654649247 | Real: 1
# 36/34389
# Predicted Label: 4, Probability: 0.9642086585239996 | Real: 1
# 37/34389
# Predicted Label: 4, Probability: 0.9780780633919386 | Real: 1
# 38/34389
# Predicted Label: 4, Probability: 0.916017227788892 | Real: 1
# 39/34389
# Predicted Label: 22, Probability: 0.8230258596300442 | Real: 1
# 40/34389
# Predicted Label: 14, Probability: 0.9590872420186344 | Real: 1
# 41/34389
# Predicted Label: 4, Probability: 0.999599750481469 | Real: 1
# 42/34389
# Predicted Label: 4, Probability: 0.9913256597472538 | Real: 1
# 43/34389
# Predicted Label: 4, Probability: 0.575277380342472 | Real: 1
# 44/34389
# Predicted Label: 14, Probability: 0.8283146390781853 | Real: 1
# 45/34389
# Predicted Label: 22, Probability: 0.5308141498969157 | Real: 1
# 46/34389
# Predicted Label: 4, Probability: 0.974131086213425 | Real: 1
# 47/34389
# Predicted Label: 4, Probability: 0.9999818185821898 | Real: 1
# 48/34389
# Predicted Label: 22, Probability: 0.9301783483285431 | Real: 1
# 49/34389
# Predicted Label: 4, Probability: 0.9092799892029568 | Real: 1
# 50/34389
# Predicted Label: 4, Probability: 0.7852561004129274 | Real: 1
# 51/34389
# Predicted Label: 14, Probability: 0.8622495660040087 | Real: 1
# 52/34389
# Predicted Label: 4, Probability: 0.7572191693926883 | Real: 1
# 53/34389
# Predicted Label: 4, Probability: 0.786106700782452 | Real: 1
# 54/34389
# Predicted Label: 22, Probability: 0.9380252059580646 | Real: 1
# 55/34389
# Predicted Label: 4, Probability: 0.9106932865048879 | Real: 1
# 56/34389
# Predicted Label: 22, Probability: 0.7959409206027112 | Real: 1
# 57/34389
# Predicted Label: 2, Probability: 0.4401786952957561 | Real: 1
# 58/34389
# Predicted Label: 14, Probability: 0.3870276250834691 | Real: 1
# 59/34389
# Predicted Label: 4, Probability: 0.7679091956992946 | Real: 1
# 60/34389
# Predicted Label: 14, Probability: 0.8977430672245446 | Real: 1
# 61/34389
# Predicted Label: 14, Probability: 0.9986308478763684 | Real: 1
# 62/34389
# Predicted Label: 4, Probability: 0.9977889433230631 | Real: 1
# 63/34389
# Predicted Label: 14, Probability: 0.999099316729155 | Real: 1
# 64/34389
# Predicted Label: 14, Probability: 0.8220465410459945 | Real: 1
# 65/34389
# Predicted Label: 14, Probability: 0.9999993498929366 | Real: 1
# 66/34389
# Predicted Label: 22, Probability: 0.7714997556981776 | Real: 1
# 67/34389
# Predicted Label: 4, Probability: 0.9999437698687799 | Real: 1
# 68/34389
# Predicted Label: 4, Probability: 0.5661742793929893 | Real: 1
# 69/34389
# Predicted Label: 4, Probability: 0.9035083245852312 | Real: 1
# 70/34389
# Predicted Label: 4, Probability: 0.4868778901517227 | Real: 1
# 71/34389
# Predicted Label: 14, Probability: 0.5315001735647671 | Real: 1
# 72/34389
# Predicted Label: 22, Probability: 0.9999917376575727 | Real: 1
# 73/34389
# Predicted Label: 4, Probability: 0.9984758454698172 | Real: 1
# 74/34389
# Predicted Label: 4, Probability: 0.9128168822652927 | Real: 1
# 75/34389
# Predicted Label: 4, Probability: 0.6398287418844981 | Real: 1
# 76/34389
# Predicted Label: 4, Probability: 0.9906422753220144 | Real: 1
# 77/34389
# Predicted Label: 14, Probability: 0.7399342806832707 | Real: 1
# 78/34389
# Predicted Label: 4, Probability: 0.9703510344364519 | Real: 1
# 79/34389
# Predicted Label: 22, Probability: 0.7725632259017317 | Real: 1
# 80/34389
# Predicted Label: 4, Probability: 0.9990274191398435 | Real: 1
# 81/34389
# Predicted Label: 22, Probability: 0.999521105127308 | Real: 1
# 82/34389
# Predicted Label: 22, Probability: 0.9995285862755433 | Real: 1
# 83/34389
# Predicted Label: 11, Probability: 0.4487054530575311 | Real: 1
# 84/34389
# Predicted Label: 4, Probability: 0.9966030665797372 | Real: 1
# 85/34389
# Predicted Label: 22, Probability: 0.7537019261485409 | Real: 1
# 86/34389
# Predicted Label: 22, Probability: 0.9999999866101278 | Real: 1
# 87/34389
# Predicted Label: 22, Probability: 0.99895896147623 | Real: 1
# 88/34389
# Predicted Label: 4, Probability: 0.9999879608416394 | Real: 1
# 89/34389
# Predicted Label: 4, Probability: 0.9706397577243243 | Real: 1
# 90/34389
# Predicted Label: 4, Probability: 0.6654325356652139 | Real: 1
# 91/34389
# Predicted Label: 22, Probability: 0.9186673158231918 | Real: 1
# 92/34389
# Predicted Label: 14, Probability: 0.9940648494069241 | Real: 1
# 93/34389
# Predicted Label: 4, Probability: 0.8012429695876839 | Real: 1
# 94/34389
# Predicted Label: 14, Probability: 0.9998114182459744 | Real: 1
# 95/34389
# Predicted Label: 22, Probability: 0.9999528124677463 | Real: 1
# 96/34389
# Predicted Label: 22, Probability: 0.7763193067157701 | Real: 1
# 97/34389
# Predicted Label: 4, Probability: 0.9999581238014713 | Real: 1
# 98/34389
# Predicted Label: 14, Probability: 0.8263716345007784 | Real: 1
# 99/34389
# Predicted Label: 22, Probability: 0.9999816286578452 | Real: 1
# 100/34389
# Predicted Label: 4, Probability: 0.775620374542216 | Real: 1
# 101/34389
# Predicted Label: 22, Probability: 0.9999753550486391 | Real: 1
